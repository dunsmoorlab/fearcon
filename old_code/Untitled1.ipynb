# %%
from mvpa_analysis import group_decode
from fc_config import data_dir

# %%
res = group_decode(imgs='tr', k=500, SC=True, S_DS=True, rmv_scram=True)
res.exp_event()
res.vis_exp_event()
# Out:
# 1 has 0 non-responses
# 2 has 0 non-responses
# 3 has 0 non-responses
# 4 has 0 non-responses
# 5 has 0 non-responses
# 6 has 0 non-responses
# 7 has 1 non-responses
# 8 has 0 non-responses
# 9 has 14 non-responses
# 10 has 0 non-responses
# 12 has 1 non-responses
# 13 has 0 non-responses
# 14 has 0 non-responses
# 15 has 0 non-responses
# 16 has 0 non-responses
# 17 has 0 non-responses
# 18 has 1 non-responses
# 19 has 0 non-responses
# 20 has 7 non-responses
